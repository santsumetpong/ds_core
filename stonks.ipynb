# %%
import yfinance as yf

# %%
ticker = yf.Ticker("AAPL")
ticker.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '(408) 996-1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...

# %%
ticker.news
# Out:
# [{'id': 'bc63a0af-0810-39ad-989a-4ad9b54a4101',
#   'content': {'id': 'bc63a0af-0810-39ad-989a-4ad9b54a4101',
#    'contentType': 'STORY',
#    'title': 'Adnoc Makes $19 Billion Takeover Bid for Australia’s Santos',
#    'description': '',
#    'summary': '(Bloomberg) -- Abu Dhabi National Oil Co. made an $18.7 billion offer for Australian fossil fuel producer Santos Ltd., the latest move by the Middle Eastern company to expand production of liquefied natural gas.Most Read from BloombergShuttered NY College Has Alumni Fighting Over Its FutureAs Part of a $45 Billion Push, ICE Prepares for a Vast Expansion of Detention SpaceDo World’s Fairs Still Matter?NYC Renters Brace for Price Hikes After Broker-Fee BanAs American Architects Gather in Boston, R',
#    'pubDate': '2025-06-16T03:33:34Z',
#    'displayTime': '2025-06-16T03:33:34Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
# ...

# %%
hist = ticker.history(period="1mo")
ticker.history_metadata
# Out:
# {'currency': 'USD',
#  'symbol': 'AAPL',
#  'exchangeName': 'NMS',
#  'fullExchangeName': 'NasdaqGS',
#  'instrumentType': 'EQUITY',
#  'firstTradeDate': 345479400,
#  'regularMarketTime': 1749844801,
#  'hasPrePostMarketData': True,
#  'gmtoffset': -14400,
#  'timezone': 'EDT',
#  'exchangeTimezoneName': 'America/New_York',
#  'regularMarketPrice': 196.45,
#  'fiftyTwoWeekHigh': 260.1,
#  'fiftyTwoWeekLow': 169.21,
#  'regularMarketDayHigh': 200.37,
#  'regularMarketDayLow': 195.77,
#  'regularMarketVolume': 50778564,
#  'longName': 'Apple Inc.',
#  'shortName': 'Apple Inc.',
#  'chartPreviousClose': 203.92,
#  'previousClose': 199.2,
#  'scale': 3,
#  'priceHint': 2,
#  'currentTradingPeriod': {'pre': {'timezone': 'EDT',
#    'start': 1750060800,
#    'end': 1750080600,
#    'gmtoffset': -14400},
#   'regular': {'timezone': 'EDT',
#    'start': 1750080600,
#    'end': 1750104000,
#    'gmtoffset': -14400},
#   'post': {'timezone': 'EDT',
#    'start': 1750104000,
# ...

# %%
ticker.actions
# Out:
#                            Dividends  Stock Splits
# Date
# 1987-05-11 00:00:00-04:00   0.000536           0.0
# 1987-06-16 00:00:00-04:00   0.000000           2.0
# 1987-08-10 00:00:00-04:00   0.000536           0.0
# 1987-11-17 00:00:00-05:00   0.000714           0.0
# 1988-02-12 00:00:00-05:00   0.000714           0.0
# ...                              ...           ...
# 2024-05-10 00:00:00-04:00   0.250000           0.0
# 2024-08-12 00:00:00-04:00   0.250000           0.0
# 2024-11-08 00:00:00-05:00   0.250000           0.0
# 2025-02-10 00:00:00-05:00   0.250000           0.0
# 2025-05-12 00:00:00-04:00   0.260000           0.0
#
# [92 rows x 2 columns]

# %%
ticker.dividends
# Out:
# Date
# 1987-05-11 00:00:00-04:00    0.000536
# 1987-08-10 00:00:00-04:00    0.000536
# 1987-11-17 00:00:00-05:00    0.000714
# 1988-02-12 00:00:00-05:00    0.000714
# 1988-05-16 00:00:00-04:00    0.000714
#                                ...
# 2024-05-10 00:00:00-04:00    0.250000
# 2024-08-12 00:00:00-04:00    0.250000
# 2024-11-08 00:00:00-05:00    0.250000
# 2025-02-10 00:00:00-05:00    0.250000
# 2025-05-12 00:00:00-04:00    0.260000
# Name: Dividends, Length: 87, dtype: float64

# %%
ticker.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64

# %%
ticker.capital_gains
# Out:
# Series([], dtype: object)

# %%
ticker.get_shares_full(start="2020-01-01", end=None)
# Out:
# 2020-01-07 00:00:00-05:00     4486889984
# 2020-01-08 00:00:00-05:00     4451420160
# 2020-01-09 00:00:00-05:00     4433600000
# 2020-01-11 00:00:00-05:00     4454550016
# 2020-01-12 00:00:00-05:00     4384030208
#                                 ...
# 2025-05-30 00:00:00-04:00    14935799808
# 2025-06-06 00:00:00-04:00    15098900480
# 2025-06-06 00:00:00-04:00    14935799808
# 2025-06-10 00:00:00-04:00    15118999552
# 2025-06-10 00:00:00-04:00    14935799808
# Length: 261, dtype: int64

# %%
ticker.quarterly_income_stmt
# Out:
#                                                        2025-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.155
# Normalized EBITDA                                   32250000000.0
# Net Income From Continuing Operation Net Minori...  24780000000.0
# Reconciled Depreciation                              2661000000.0
# Reconciled Cost Of Revenue                          50492000000.0
# EBITDA                                              32250000000.0
# EBIT                                                29589000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   24780000000.0
# Net Income From Continuing And Discontinued Ope...  24780000000.0
# ...

# %%
ticker.balance_sheet
# Out:
#                                                       2024-09-30  \
# Treasury Shares Number                                       NaN
# Ordinary Shares Number                             15116786000.0
# Share Issued                                       15116786000.0
# Net Debt                                           76686000000.0
# Total Debt                                        106629000000.0
# ...                                                          ...
# Cash Cash Equivalents And Short Term Investments   65171000000.0
# Other Short Term Investments                       35228000000.0
# Cash And Cash Equivalents                          29943000000.0
# Cash Equivalents                                    2744000000.0
# Cash Financial                                     27199000000.0
#
#                                                       2023-09-30  \
# Treasury Shares Number                                       0.0
# ...

# %%
ticker.quarterly_balance_sheet
# Out:
#                                                      2025-03-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                            14939315000.0
# Share Issued                                      14939315000.0
# Net Debt                                          70024000000.0
# Total Debt                                        98186000000.0
# ...                                                         ...
# Cash Cash Equivalents And Short Term Investments  48498000000.0
# Other Short Term Investments                      20336000000.0
# Cash And Cash Equivalents                         28162000000.0
# Cash Equivalents                                   3101000000.0
# Cash Financial                                    25061000000.0
#
#                                                      2024-12-31  \
# Treasury Shares Number                                      NaN
# Ordinary Shares Number                            15037874000.0
# ...

# %%
ticker.cashflow
# Out:
#                                                     2024-09-30  \
# Free Cash Flow                                  108807000000.0
# Repurchase Of Capital Stock                     -94949000000.0
# Repayment Of Debt                                -9958000000.0
# Issuance Of Debt                                           0.0
# Issuance Of Capital Stock                                  NaN
# Capital Expenditure                              -9447000000.0
# Interest Paid Supplemental Data                            NaN
# Income Tax Paid Supplemental Data                26102000000.0
# End Cash Position                                29943000000.0
# Beginning Cash Position                          30737000000.0
# Changes In Cash                                   -794000000.0
# Financing Cash Flow                            -121983000000.0
# Cash Flow From Continuing Financing Activities -121983000000.0
# Net Other Financing Charges                      -5802000000.0
# ...

# %%
ticker.quarterly_cashflow
# Out:
#                                                    2025-03-31     2024-12-31  \
# Free Cash Flow                                  20881000000.0  26995000000.0
# Repurchase Of Capital Stock                    -25898000000.0 -23606000000.0
# Repayment Of Debt                                 976000000.0  -8953000000.0
# Issuance Of Debt                                          NaN            NaN
# Capital Expenditure                             -3071000000.0  -2940000000.0
# Interest Paid Supplemental Data                           NaN            NaN
# Income Tax Paid Supplemental Data               13032000000.0  18651000000.0
# End Cash Position                               28162000000.0  30299000000.0
# Beginning Cash Position                         30299000000.0  29943000000.0
# Changes In Cash                                 -2137000000.0    356000000.0
# Financing Cash Flow                            -29006000000.0 -39371000000.0
# ...

# %%
ticker.major_holders
# Out:
# Breakdown                          Value
# insidersPercentHeld              0.02085
# institutionsPercentHeld          0.62893
# institutionsFloatPercentHeld     0.64232
# institutionsCount             7020.00000

# %%
ticker.institutional_holders
# Out:
#   Date Reported                         Holder  pctHeld      Shares  \
# 0    2025-03-31             Vanguard Group Inc   0.0938  1400790809
# 1    2025-03-31                 Blackrock Inc.   0.0763  1140202870
# 2    2025-03-31       State Street Corporation   0.0399   596025766
# 3    2025-03-31  Geode Capital Management, LLC   0.0234   349807156
# 4    2025-03-31                       FMR, LLC   0.0220   328100180
# 5    2025-03-31        Berkshire Hathaway, Inc   0.0201   300000000
# 6    2025-03-31                 Morgan Stanley   0.0162   241221800
# 7    2025-03-31  Price (T.Rowe) Associates Inc   0.0144   214703055
# 8    2025-03-31            JPMORGAN CHASE & CO   0.0133   198745598
# 9    2024-12-31                    NORGES BANK   0.0125   187160162
#
#           Value  pctChange
# 0  275185350153     0.0036
# 1  223992850331     0.0149
# 2  117089259911     0.0009
# 3   68719614728     0.0283
# 4   64455279359    -0.0396
# 5   58934999084     0.0000
# ...

# %%
ticker.mutualfund_holders
# Out:
#   Date Reported                                             Holder  pctHeld  \
# 0    2025-03-31  VANGUARD INDEX FUNDS-Vanguard Total Stock Mark...   0.0318
# 1    2025-03-31       VANGUARD INDEX FUNDS-Vanguard 500 Index Fund   0.0279
# 2    2025-04-30  Fidelity Concord Street Trust-Fidelity 500 Ind...   0.0126
# 3    2025-04-30                             SPDR S&P 500 ETF TRUST   0.0121
# 4    2025-04-30             iShares Trust-iShares Core S&P 500 ETF   0.0119
# 5    2025-03-31    VANGUARD INDEX FUNDS-Vanguard Growth Index Fund   0.0098
# 6    2025-04-30                        Invesco QQQ Trust, Series 1   0.0083
# 7    2025-03-31  VANGUARD INSTITUTIONAL INDEX FUNDS-Vanguard In...   0.0062
# 8    2025-02-28  VANGUARD WORLD FUND-Vanguard Information Techn...   0.0048
# 9    2025-04-30      iShares Trust-iShares Russell 1000 Growth ETF   0.0035
#
#       Shares        Value  pctChange
# 0  474593499  93233891430     0.0021
# 1  417401576  81998538331     0.0201
# ...

# %%
ticker.insider_transactions
# Out:
#     Shares      Value URL                                      Text  \
# 0     4486   933955.0               Sale at price 208.19 per share.
# 1     4570   941420.0               Sale at price 206.00 per share.
# 2     7373        NaN
# 3    16458        NaN
# 4    38822  8683252.0      Sale at price 221.68 - 224.62 per share.
# ..     ...        ...  ..                                       ...
# 74  136268        NaN
# 75  511000        NaN
# 76    5600        0.0           Stock Gift at price 0.00 per share.
# 77   15419  2753217.0               Sale at price 178.56 per share.
# 78   31896        NaN
#
#               Insider                 Position Transaction Start Date  \
# 0   KONDO CHRISTOPHER                  Officer             2025-05-12
# 1        PAREKH KEVAN  Chief Financial Officer             2025-04-23
# 2   KONDO CHRISTOPHER                  Officer             2025-04-15
# 3        PAREKH KEVAN  Chief Financial Officer             2025-04-15
# ...

# %%
ticker.insider_purchases
# Out:
#        Insider Purchases Last 6m       Shares  Trans
# 0                      Purchases     476616.0     13
# 1                          Sales     293023.0      7
# 2    Net Shares Purchased (Sold)     183593.0     20
# 3      Total Insider Shares Held  311412000.0   <NA>
# 4  % Net Shares Purchased (Sold)        0.001   <NA>
# 5                   % Buy Shares        0.002   <NA>
# 6                  % Sell Shares          0.0   <NA>

# %%
ticker.insider_roster_holders
# Out:
#                  Name                 Position URL  \
# 0   ADAMS KATHERINE L          General Counsel
# 1      AUSTIN WANDA M                 Director
# 2      COOK TIMOTHY D  Chief Executive Officer
# 3         GORSKY ALEX                 Director
# 4   KONDO CHRISTOPHER                  Officer
# 5   LEVINSON ARTHUR D                 Director
# 6     O'BRIEN DEIRDRE                  Officer
# 7        PAREKH KEVAN  Chief Financial Officer
# 8      SUGAR RONALD D                 Director
# 9  WILLIAMS JEFFREY E  Chief Operating Officer
#
#                          Most Recent Transaction Latest Transaction Date  \
# 0                                           Sale              2025-04-02
# 1  Conversion of Exercise of derivative security              2025-01-31
# 2                                           Sale              2025-04-02
# 3  Conversion of Exercise of derivative security              2025-01-31
# ...

# %%
ticker.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          6   20    17     2           1
# 1    -1m          7   21    16     2           1
# 2    -2m          7   23    16     1           1
# 3    -3m          7   21    14     2           1

# %%
ticker.recommendations_summary
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          6   20    17     2           1
# 1    -1m          7   21    16     2           1
# 2    -2m          7   23    16     1           1
# 3    -3m          7   21    14     2           1

# %%
ticker.upgrades_downgrades
# Out:
#                                   Firm     ToGrade   FromGrade Action  \
# GradeDate
# 2025-06-10 13:52:03     Morgan Stanley  Overweight  Overweight   reit
# 2025-06-10 13:43:30            Wedbush  Outperform  Outperform   reit
# 2025-06-10 13:10:25  B of A Securities         Buy         Buy   reit
# 2025-06-10 10:23:40            Needham        Hold        Hold   reit
# 2025-06-05 17:37:27     Morgan Stanley  Overweight  Overweight   reit
# ...                                ...         ...         ...    ...
# 2016-04-27 11:29:54        Cowen & Co.  Outperform               main
# 2016-04-27 11:17:22      Goldman Sachs         Buy               main
# 2016-04-27 11:17:02          Macquarie         Buy               main
# 2016-04-27 11:16:24        Oppenheimer     Perform  Outperform   down
# 2012-09-12 11:51:00      Hudson Square         Buy               main
#
#                     priceTargetAction  currentPriceTarget
# GradeDate
# ...

# %%
ticker.earnings_dates
# Out:
#                            EPS Estimate  Reported EPS  Surprise(%)
# Earnings Date
# 2026-04-29 06:59:00-04:00           NaN           NaN          NaN
# 2026-01-28 16:00:00-05:00           NaN           NaN          NaN
# 2025-10-29 06:59:00-04:00           NaN           NaN          NaN
# 2025-07-30 06:59:00-04:00           NaN           NaN          NaN
# 2025-05-01 16:30:00-04:00          1.63          1.65         1.41
# 2025-01-30 16:31:00-05:00          2.35          2.40         2.15
# 2024-10-31 16:31:00-04:00          1.60          1.64         2.35
# 2024-08-01 16:30:00-04:00          1.35          1.40         3.99
# 2024-05-02 16:31:00-04:00          1.50          1.53         1.97
# 2024-02-01 16:00:00-05:00          2.10          2.18         3.90
# 2023-11-02 16:30:00-04:00          1.39          1.46         4.92
# 2023-08-03 16:30:00-04:00          1.19          1.26         5.49

# %%
ticker.isin
# Out:
# 'US0378331005'

# %%
ticker.options
# Out:
# ('2025-06-20',
#  '2025-06-27',
#  '2025-07-03',
#  '2025-07-11',
#  '2025-07-18',
#  '2025-07-25',
#  '2025-08-01',
#  '2025-08-15',
#  '2025-09-19',
#  '2025-10-17',
#  '2025-11-21',
#  '2025-12-19',
#  '2026-01-16',
#  '2026-02-20',
#  '2026-03-20',
#  '2026-06-18',
#  '2026-09-18',
#  '2026-12-18',
#  '2027-01-15',
#  '2027-06-17',
#  '2027-12-17')

# %%
ticker.get_calendar()
# Out:
# {'Dividend Date': datetime.date(2025, 5, 15),
#  'Ex-Dividend Date': datetime.date(2025, 5, 12),
#  'Earnings Date': [datetime.date(2025, 7, 30), datetime.date(2025, 8, 4)],
#  'Earnings High': 1.51,
#  'Earnings Low': 1.34,
#  'Earnings Average': 1.42413,
#  'Revenue High': 90104000000,
#  'Revenue Low': 86919000000,
#  'Revenue Average': 88630845280}

# %%
# ticker.shares
# Out:
# ---------------------------------------------------------------------------
# YFNotImplementedError                     Traceback (most recent call last)
# <ipython-input-61-2148786090> in <cell line: 0>()
# ----> 1 ticker.shares
#
# /usr/local/lib/python3.11/dist-packages/yfinance/ticker.py in shares(self)
#     153     @property
#     154     def shares(self) -> _pd.DataFrame:
# --> 155         return self.get_shares()
#     156
#     157     @property
#
# /usr/local/lib/python3.11/dist-packages/yfinance/base.py in get_shares(self, proxy, as_dict)
#     561             self._data._set_proxy(proxy)
#     562
# --> 563         data = self._fundamentals.shares
#     564         if as_dict:
#     565             return data.to_dict()
#
# /usr/local/lib/python3.11/dist-packages/yfinance/scrapers/fundamentals.py in shares(self)
#      40     def shares(self) -> pd.DataFrame:
#      41         if self._shares is None:
# ---> 42             raise YFNotImplementedError('shares')
# ...

# %%
ticker.fast_info
# Out:
# lazy-loading dict with keys = ['currency', 'dayHigh', 'dayLow', 'exchange', 'fiftyDayAverage', 'lastPrice', 'lastVolume', 'marketCap', 'open', 'previousClose', 'quoteType', 'regularMarketPreviousClose', 'shares', 'tenDayAverageVolume', 'threeMonthAverageVolume', 'timezone', 'twoHundredDayAverage', 'yearChange', 'yearHigh', 'yearLow']

# %%
ticker.sec_filings
# Out:
# [{'date': datetime.date(2025, 5, 2),
#   'epochDate': 1746144000,
#   'type': '10-Q',
#   'title': 'Periodic Financial Reports',
#   'edgarUrl': 'https://finance.yahoo.com/sec-filing/AAPL/0000320193-25-000057_320193',
#   'exhibits': {'10-Q': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000057/aapl-20250329.htm',
#    'EX-31.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000057/a10-qexhibit31103292025.htm',
#    'EX-31.2': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000057/a10-qexhibit31203292025.htm',
#    'EX-32.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000057/a10-qexhibit32103292025.htm',
#    'EXCEL': 'https://s3.amazonaws.com/finance-pri-uw2/sec-filings/0000320193/000032019325000057/Financial_Report.xlsx'},
#   'maxAge': 1},
#  {'date': datetime.date(2025, 5, 1),
#   'epochDate': 1746057600,
#   'type': '8-K',
#   'title': 'Corporate Changes & Voting Matters',
# ...

# %%
# ticker.earnings

# %%
# ticker.quarterly_earnings
# Out:
# /usr/local/lib/python3.11/dist-packages/yfinance/scrapers/fundamentals.py:36: DeprecationWarning: 'Ticker.earnings' is deprecated as not available via API. Look for "Net Income" in Ticker.income_stmt.
#   warnings.warn("'Ticker.earnings' is deprecated as not available via API. Look for \"Net Income\" in Ticker.income_stmt.", DeprecationWarning)

# %%
ticker.incomestmt
# Out:
#                                                         2024-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.241
# Normalized EBITDA                                   134661000000.0
# Net Income From Continuing Operation Net Minori...   93736000000.0
# Reconciled Depreciation                              11445000000.0
# Reconciled Cost Of Revenue                          210352000000.0
# EBITDA                                              134661000000.0
# EBIT                                                123216000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    93736000000.0
# Net Income From Continuing And Discontinued Ope...   93736000000.0
# ...

# %%
# ticker.quarterly_incomestmt
# Out:
#                                                        2025-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.155
# Normalized EBITDA                                   32250000000.0
# Net Income From Continuing Operation Net Minori...  24780000000.0
# Reconciled Depreciation                              2661000000.0
# Reconciled Cost Of Revenue                          50492000000.0
# EBITDA                                              32250000000.0
# EBIT                                                29589000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   24780000000.0
# Net Income From Continuing And Discontinued Ope...  24780000000.0
# ...

# %%
ticker.ttm_incomestmt
# Out:
#                                                         2025-03-31
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.233893
# Normalized EBITDA                                   138866000000.0
# Net Income From Continuing Operation Net Minori...   97294000000.0
# Reconciled Depreciation                              11502000000.0
# Reconciled Cost Of Revenue                          213667000000.0
# EBITDA                                              138866000000.0
# EBIT                                                127364000000.0
# Normalized Income                                    97294000000.0
# Net Income From Continuing And Discontinued Ope...   97294000000.0
# Total Expenses                                      273002000000.0
# Total Operating Income As Reported                  127364000000.0
# Diluted Average Shares                               15199507000.0
# ...

# %%
ticker.financials
# Out:
#                                                         2024-09-30  \
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                           0.241
# Normalized EBITDA                                   134661000000.0
# Net Income From Continuing Operation Net Minori...   93736000000.0
# Reconciled Depreciation                              11445000000.0
# Reconciled Cost Of Revenue                          210352000000.0
# EBITDA                                              134661000000.0
# EBIT                                                123216000000.0
# Net Interest Income                                            NaN
# Interest Expense                                               NaN
# Interest Income                                                NaN
# Normalized Income                                    93736000000.0
# Net Income From Continuing And Discontinued Ope...   93736000000.0
# ...

# %%
ticker.quarterly_financials
# Out:
#                                                        2025-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.155
# Normalized EBITDA                                   32250000000.0
# Net Income From Continuing Operation Net Minori...  24780000000.0
# Reconciled Depreciation                              2661000000.0
# Reconciled Cost Of Revenue                          50492000000.0
# EBITDA                                              32250000000.0
# EBIT                                                29589000000.0
# Net Interest Income                                           NaN
# Interest Expense                                              NaN
# Interest Income                                               NaN
# Normalized Income                                   24780000000.0
# Net Income From Continuing And Discontinued Ope...  24780000000.0
# ...

# %%
ticker.ttm_financials
# Out:
#                                                         2025-03-31
# Tax Effect Of Unusual Items                                    0.0
# Tax Rate For Calcs                                        0.233893
# Normalized EBITDA                                   138866000000.0
# Net Income From Continuing Operation Net Minori...   97294000000.0
# Reconciled Depreciation                              11502000000.0
# Reconciled Cost Of Revenue                          213667000000.0
# EBITDA                                              138866000000.0
# EBIT                                                127364000000.0
# Normalized Income                                    97294000000.0
# Net Income From Continuing And Discontinued Ope...   97294000000.0
# Total Expenses                                      273002000000.0
# Total Operating Income As Reported                  127364000000.0
# Diluted Average Shares                               15199507000.0
# ...

# %%
ticker.ttm_cash_flow
# Out:
#                                                     2025-03-31
# Free Cash Flow                                   98486000000.0
# Repurchase Of Capital Stock                    -101109000000.0
# Repayment Of Debt                               -10803000000.0
# Capital Expenditure                             -11070000000.0
# Income Tax Paid Supplemental Data                43254000000.0
# End Cash Position                                28162000000.0
# Beginning Cash Position                          33921000000.0
# Changes In Cash                                  -5759000000.0
# Financing Cash Flow                            -129342000000.0
# Cash Flow From Continuing Financing Activities -129342000000.0
# Net Other Financing Charges                      -6077000000.0
# Cash Dividends Paid                             -15313000000.0
# Common Stock Dividend Paid                      -15313000000.0
# Net Common Stock Issuance                      -101109000000.0
# ...

# %%
ticker.analyst_price_targets
# Out:
# {'current': 196.45,
#  'high': 300.0,
#  'low': 170.62,
#  'mean': 228.85326,
#  'median': 232.5}

# %%
ticker.earnings_estimate
# Out:
#             avg      low  high  yearAgoEps  numberOfAnalysts  growth
# period
# 0q      1.41586  1.32000  1.47     1.40000                29  0.0113
# +1q     1.65694  1.47204  1.84     0.97000                28  0.7082
# 0y      7.17664  6.82000  7.63     6.08000                44  0.1804
# +1y     7.82021  6.83000  9.00     7.17664                43  0.0897

# %%
ticker.revenue_estimate
# Out:
#                  avg           low          high  numberOfAnalysts  \
# period
# 0q       88630845280   86919000000   90104000000                28
# +1q      97742457700   91149000000  103539000000                26
# 0y      407116592330  398622000000  431783000000                40
# +1y     430961977690  408100000000  477463000000                43
#
#         yearAgoRevenue  growth
# period
# 0q         85777000000  0.0333
# +1q        94930000000  0.0296
# 0y        391035000000  0.0411
# +1y       407116592330  0.0586

# %%
ticker.earnings_history
# Out:
#             epsActual  epsEstimate  epsDifference  surprisePercent
# quarter
# 2024-06-30       1.40      1.34155           0.06           0.0436
# 2024-09-30       0.97      0.94654           0.02           0.0248
# 2024-12-31       2.40      2.34102           0.06           0.0252
# 2025-03-31       1.65      1.62253           0.03           0.0169

# %%
ticker.eps_trend
# Out:
#         current  7daysAgo  30daysAgo  60daysAgo  90daysAgo
# period
# 0q      1.41586   1.41655    1.41571    1.46607    1.49487
# +1q     1.65694   1.65873    1.65609    1.73310    1.77058
# 0y      7.17664   7.17664    7.17609    7.25558    7.31881
# +1y     7.82021   7.82021    7.82331    8.02344    8.18489

# %%
ticker.eps_revisions
# Out:
#         upLast7days  upLast30days  downLast30days  downLast7Days
# period
# 0q                0             1               2              1
# +1q               0             2               1              1
# 0y                0             2               5              1
# +1y               0             1               5              1

# %%
ticker.growth_estimates
# Out:
#         stockTrend  indexTrend
# period
# 0q          0.0172      0.1313
# +1q         0.0121      0.0240
# 0y          0.0651      0.0754
# +1y         0.0929      0.1408
# LTG            NaN      0.1220

# %%
ticker.sustainability
# Out:
#                                                                            esgScores
# maxAge                                                                         86400
# totalEsg                                                                       18.99
# environmentScore                                                                2.44
# socialScore                                                                     7.98
# governanceScore                                                                 8.58
# ratingYear                                                                      2025
# ratingMonth                                                                        6
# highestControversy                                                               3.0
# peerCount                                                                        238
# esgPerformance                                                              LAG_PERF
# ...

# %%
# ticker.funds_data
